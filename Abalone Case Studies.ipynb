# %% [markdown]
# Import All The Required Libraries such as Numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('abalone.csv')
print(df)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# This function is used to access the first 5 rows of a dataframe.

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# This function is used to access the last 5 rows of a dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# This function is used to print the information given in our Dataframe. This function gives information about the Data type(float, object, int), columns.

# %%
df.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %% [markdown]
# This function gives information about any Null Value is present in our Data frame. if all the values are False as shown above then we say there is not any null value is present in our data frame.

# %%
df.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %% [markdown]
# This function gives information about any data is missing or Not.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# This function gives information how many missing value is present in our Dataframe.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# With the help of Double sum Function we find our missing value is zero.

# %% [markdown]
# means No Null Value is Present in Our Dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# This function gives information about the Description of our Data Frame.

# %%
df['Sex'].replace(['M', 'F','I'],
                        [0, 1,2], inplace=True)

# %% [markdown]
# In above Input we convert Categorized Data(Sex) into Numerical Form, so that all our dataframe is in Numerical Format.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load the Libraries in Above Input which is used to find the output.

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %% [markdown]
# Here above Figure Shows Histogram Plot, The Bins=25 shows here, that our graph is divided into 25 bars, if we use Bins= 15, than our graph is divided into 15 bars, we use 25 here because our data set is very large.
# figsize is used here to show the size of each Graph.For Example:- Here (10,10) shows the Breadth and Height of Each Individual Graph.

# %%
#plotting Heatmap
plt.figure(figsize=[19,10],facecolor='blue')
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here, we notice that age factor is not related to anyone. whole weight is almost related to all other factors except age. Height Factor is also different as compare to length, diameter,  whole weight, Shucked weight, Viscera Weight, Shell Weight.

# %% [markdown]
# Use a different color palette:

# %%
sns.countplot(x = 'Sex' , data = df , palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# We use countplot here, Because Sex Column is a categorical type and it is used to count how many male members are there, Female members are there and Infant members are there.

# %%
numerical_features=df.select_dtypes(include = [np.number]).columns

# %%
numerical_features
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# we see in our dataset that Sex Column is a Categorical type & we also convert in above input sex column into Numerical type already.
# So in our numerical_feature as we seen All columns show here.

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    0   0.455     0.365   0.095        0.5140          0.2245
# 1    0   0.350     0.265   0.090        0.2255          0.0995
# 2    1   0.530     0.420   0.135        0.6770          0.2565
# 3    0   0.440     0.365   0.125        0.5160          0.2155
# 4    2   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# we already convert sex data into numeric one in above slide, so that all show here in numeric form, Male show here=0, Female show here =1, Infant Show Here = 2.

# %%
plt.scatter(x = df['Viscera weight'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# First of All, Scatter plot Diagram is a Data Visualization Technique and it is plot when Both X And Y axis are in a Numerical Form, if any of the case one is categorical and other one is Numerical than Graph is not Plotted. Here, Grid shows the Lines
# In above Diagram, X Shows Viscera weight & y Shows Rings. This is big data set if we try to explain then, the first value of Viscera Weight= 0.10 and First value of Ring is 15, then where both point Coincide then a Dot is plot,Similarly all 4176 data our Scatter plot Shown above

# %%
plt.scatter(x = df['Shell weight'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Shell weight & y Shows Rings. The first value of Shell Weight= 0.15 and First value of Ring is 15, then where both point Coincide then a Dot is plot,Similarly all 4176 data our Scatter plot Shown above

# %%
plt.scatter(x = df['Shucked weight'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Shucked weight & y Shows Rings. The first value of Shucked Weight= 0.2245 and First value of Ring is 15, then where both point Coincide then a Dot is plot,Similarly all 4176 data our Scatter plot Shown above

# %%
plt.scatter(x = df['Whole weight'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Whole weight & y Shows Rings. The first value of Whole Weight= 0.514 and First value of Ring is 15, then where both point Coincide then a Dot is plot,Similarly all 4176 data our Scatter plot Shown above

# %%
plt.scatter(x = df['Height'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Height weight & y Shows Rings. The first value of Height= 0.095 and First value of Ring is 15. Then  both point Coincide then a Dot is plot. In this Diagram We show All Values of Height is less than 1 so that our scatter plot is Different from other previous one plotted above. Similarly all 4176 data our Scatter plot Shown above.

# %%
plt.scatter(x = df['Diameter'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Diameter & y Shows Rings. The first value of Diameter= 0.365 and First value of Ring is 15, then where both point Coincide then a Dot is plot, Mostly value are 0.3 or above so that ou major scatter Plot is moving from 0.3 to 0.6. So that we draw for all 4176 data & our Scatter plot Shown above.

# %%
plt.scatter(x = df['Length'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Length & y Shows Rings. The first value of Length= 0.365 and First value of Ring is 15, then where both point Coincide then a Dot is plot, Mostly value are 0.3 or above so that ou major scatter Plot is moving from 0.3 to 0.6. So that we draw for all 4176 data & our Scatter plot Shown above.

# %%
plt.scatter(x = df['Sex'] , y = df['Rings'])
plt.grid()

# %% [markdown]
# In above Diagram, X Shows Sex & y Shows Rings. We give the Sex value in above input already such as male=0, Female=1, Infant=2, so here shown 3 lines in 0,1,2 and Similarly in Y axis Rings are plotted,then where both point Coincide then a Dot is plot. So that we draw for all 4176 data & our Scatter plot Shown above.

# %%
plt.figure(figsize=(10,5))
sns.jointplot(data=df, x='Rings', y='Height' , kind='reg');
sns.jointplot(data=df, x='Rings', y='Shell weight' , kind='reg');

# %% [markdown]
# The above Joint plot is similar to scatter plot, In this we create a dataframe first of the given dataset, and with the help of Pandas Library and Numpy we pass into Jointplot Function. Here rig shows, It is used to plot data and a linear regression model fit.

# %%
plt.figure(figsize=(10,15))
plt.subplot(3,1,1)
sns.violinplot(data=df,x='Rings', y='Diameter')
plt.subplot(3,1,2)
sns.violinplot(data=df,x='Rings', y='Height')
plt.subplot(3,1,1)
sns.violinplot(data=df,x='Rings', y='Length')
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %% [markdown]
# As we know violin plot is called as Box plot + KDE plot. The mid line shows Box plot and left side shows normal Distribution and right side shows mirror of left side. while complete drawing. The centre line shows here, upper line shows maximum value and lower line shows minimum value. In Rings and Height Case, Minimum Value of Height is 0.12 and the value of Rings is Varying such as 12 or 15 like that. so that our plot shown above.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x='Sex', y='Rings');

# %% [markdown]
# The above fig shows Box plot, here last line shows Minimum Value, Mid line called as median and Top line called as Maximum Value and after the minimum and maximum Value Some dots are there called as outliers.
# Here Sex Column is divided into 3 Values that is 0,1,2 and Rings value is also given as low as 5 and max as approx 17, Here we draw a Vertical Box Plot.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x='Sex', y='Height');

# %% [markdown]
# The above fig shows Box plot, here last line shows Minimum Value, Mid line called as median and Top line called as Maximum Value and after the minimum and maximum Value Some dots are there called as outliers.
# Here Sex Column is divided into 3 Values that is 0,1,2 and Height value is also given as low as 0.1 and max as approx 0.25, Here we draw a Vertical Box Plot.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x='Sex', y='Shell weight');

# %% [markdown]
# The above fig shows Box plot, here last line shows Minimum Value, Mid line called as median and Top line called as Maximum Value and after the minimum and maximum Value Some dots are there called as outliers.
# Here Sex Column is divided into 3 Values that is 0,1,2 and Shell Weight is also given as low as 0.15 and max as approx 0.6, Here we draw a Vertical Box Plot.

# %%
X = df.drop('Rings',axis=1)
y = df['Rings']

# %% [markdown]
# Here we drop Rings, Because we Calculate the Rings

# %%
#splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=1) 
X_train.shape , X_test.shape ,y_train.shape , y_test.shape
# Out:
# ((2923, 8), (1254, 8), (2923,), (1254,))

# %% [markdown]
# The Data is Splitted into Trainning and Testing Sets in above input

# %% [markdown]
# # Here We use Support Vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# SVC is used for classification, regression and outliers detection.

# %%
#Test Model
pred = svc.predict(X_test)
pred
# Out:
# array([9, 9, 9, ..., 9, 9, 6], dtype=int64)

# %% [markdown]
# Here, we predict the SVC values in X_test

# %%
y_test
# Out:
# 17      10
# 1131     8
# 299      9
# 1338    10
# 2383    16
#         ..
# 802      9
# 3016     7
# 2886     8
# 2580     8
# 2814     4
# Name: Rings, Length: 1254, dtype: int64

# %% [markdown]
# Here, we predict the SVC values in y_test

# %% [markdown]
# # Here We use Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dt.predict(X_test)
pred
# Out:
# array([9, 9, 8, ..., 9, 9, 6], dtype=int64)

# %%
y_test
# Out:
# 17      10
# 1131     8
# 299      9
# 1338    10
# 2383    16
#         ..
# 802      9
# 3016     7
# 2886     8
# 2580     8
# 2814     4
# Name: Rings, Length: 1254, dtype: int64

# %% [markdown]
# lets apply the Given Input Data and so that we calculate the Rings

# %%
input_data = (1,0.545,0.425,0.125,0.768,0.294,0.1495,0.26)

# changing the input data into numpy data
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = dt.predict(input_data_reshaped)
print(prediction)
print(prediction+1.5)
# Out:
# [11]
# [12.5]

# %% [markdown]
# Lets apply Different Given Input Data and at last add 1.5 for finding the Age

# %%
input_data = (0,0.44,0.365,0.125,0.516,0.2155,0.114,0.155)

# changing the input data into numpy data
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = svc.predict(input_data_reshaped)
print(prediction)
print(prediction+1.5)
# Out:
# [9]
# [10.5]

# %% [markdown]
# Thanks
